# %%
import numpy as np
import pandas as pd

# %%
student = ['Lê Quốc Thiện', 'Lê Thị Thanh Xuân', 'Đỗ Hoàng Khánh', 'Thân Văn Đông', 'Vũ Huỳnh', 'Nguyễn Hữu Linh Chi', 'Trịnh Thu Hương', 'Phú', 
          'Nguyễn Thế Hồng Khê', 'Phạm Văn Sĩ', 'Văn Hải Dương', 'Nguyễn Đức Tuấn Vinh', 'Nguyễn Hoàng Khánh An', 'Lê Nguyên Khang', 'Nguyễn Quí Long', 
          'Lê Phạm Ngọc Thảo', 'Phạm Nguyễn Thu Hằng']

# %%
np.random.shuffle(student)
student_df = pd.DataFrame(student, columns=['grader'])
np.random.shuffle(student)
student_df['student'] = student
student_df
# Out:
#                    grader                student
# 0     Nguyễn Thế Hồng Khê          Thân Văn Đông
# 1             Phạm Văn Sĩ        Lê Nguyên Khang
# 2           Văn Hải Dương                    Phú
# 3     Nguyễn Hữu Linh Chi   Nguyễn Đức Tuấn Vinh
# 4                Vũ Huỳnh        Nguyễn Quí Long
# 5         Lê Nguyên Khang        Trịnh Thu Hương
# 6   Nguyễn Hoàng Khánh An      Lê Thị Thanh Xuân
# 7          Đỗ Hoàng Khánh    Nguyễn Thế Hồng Khê
# 8           Thân Văn Đông          Văn Hải Dương
# 9    Phạm Nguyễn Thu Hằng          Lê Quốc Thiện
# 10        Nguyễn Quí Long      Lê Phạm Ngọc Thảo
# 11          Lê Quốc Thiện               Vũ Huỳnh
# 12      Lê Thị Thanh Xuân         Đỗ Hoàng Khánh
# 13                    Phú  Nguyễn Hoàng Khánh An
# 14      Lê Phạm Ngọc Thảo            Phạm Văn Sĩ
# 15   Nguyễn Đức Tuấn Vinh    Nguyễn Hữu Linh Chi
# 16        Trịnh Thu Hương   Phạm Nguyễn Thu Hằng

# %%
student_df.to_excel('grader.xlsx', index=False)
