# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
# %matplotlib inline
df = pd.read_csv("FuelConsumption.csv")

x = np.arange(5,1)
x

# plt.figure(figsize=(15,3))
# plt.plot([3,2,3,4,5,6], [2,4,9,8,10,12], "go")

# plt.title('asdasda dasd asdasd')
# plt.xlabel('Truc x ')
# plt.ylabel('Truc y ')
# plt.show()

# %%
()
